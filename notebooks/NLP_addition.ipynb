# %%
import os
os.chdir('..')
from src.util import *
from src.recommender import MovieRecommender
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from src.compute_similarities import *

# %%
os.getcwd()
# Out:
# '/Users/kylecaron/Desktop/dsi-recommender-case-study'

# %%
#Takes very long time to run when n>100k
generate_file_split(random_subset(800000), 0.8)

# %%
train = pd.read_csv('data/ctrain.csv')
test = pd.read_csv('data/ctest.csv')
request_data = pd.read_csv('data/crequests.csv')

# %% [markdown]
# # Pad ratings in training set

# %%
train_padded = fill_ratings(train, 20)

# %%
len(train_padded)
# Out:
# 6512505

# %% [markdown]
# # Fit recommender model

# %% [markdown]
# #### Original Training set

# %%
reco_instance = MovieRecommender()
fit_model = reco_instance.fit(train)
predictions = reco_instance.transform(request_data)

# %%
RMSE(predictions, test)
# Out:
# 1.2828647387466954

# %% [markdown]
# ### Padded Training set

# %%
reco_instance = MovieRecommender()
fit_model = reco_instance.fit(train_padded)
predictions = reco_instance.transform(request_data)

# %%
RMSE(predictions, test)
# Out:
# 1.245438531681923
